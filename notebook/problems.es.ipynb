# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
from scipy.stats import norm

## definir funciones distribución normal
def dnorm(x, mean=0, sd=1):
    result =  norm.pdf(x, loc=mean, scale=sd)
    return result

def pnorm(q, mean=0, sd=1):
    result = norm.cdf(q, loc=mean, scale=sd)
    return result

def qnorm(p, mean=0, sd=1):
    result = norm.ppf(p, loc=mean, scale=sd)
    return result

def rnorm(n, mean=0, sd=1):
    result = norm.rvs(loc=mean, scale=sd, size=n)
    return result

## Imprimir ejemplos dist normal:
np.random.seed(42)
mean = 0
sd = 1
print("--- Distribución Normal ---")
print(f"Densidad de probabilidad en x=0 para la distribución Normal(0,1): {dnorm(0, mean, sd):.2f}")
print(f"Probabilidad acumulada en x=1.96 para la distribución Normal(0,1): {pnorm(1.96, mean, sd):.2f}")
print(f"¿Qué valor de una distribución Normal(0,1) tiene una probabilidad acumulada de 0.95? {qnorm(0.95, mean, sd):.2f}")
print(f"5 valores aleatorios de una distribución Normal(0,1)): {rnorm(5, mean, sd)}")

data = rnorm(2000, mean , sd )

pdf = dnorm(data, mean = mean, sd = sd)
cdf = pnorm(data, mean = mean, sd = sd)
ppf = qnorm(data, mean = mean, sd = sd)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pdf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# --- Distribución Normal ---
# Densidad de probabilidad en x=0 para la distribución Normal(0,1): 0.40
# Probabilidad acumulada en x=1.96 para la distribución Normal(0,1): 0.98
# ¿Qué valor de una distribución Normal(0,1) tiene una probabilidad acumulada de 0.95? 1.64
# 5 valores aleatorios de una distribución Normal(0,1)): [ 0.49671415 -0.1382643   0.64768854  1.52302986 -0.23415337]

# %%
from scipy.stats import uniform

## definir funciones distribución normal
def duniform(x, min_val=0, max_val=1):
    result = uniform.pdf(x, loc=min_val, scale=max_val-min_val)
    return result

def puniform(q, min_val=0, max_val=1):
    result = uniform.cdf(q, loc=min_val, scale=max_val-min_val)
    return result

def quniform(p, min_val=0, max_val=1):
    result = uniform.ppf(p, loc=min_val, scale=max_val-min_val)
    return result

def runiform(n, min_val=0, max_val=1):
    result = uniform.rvs(loc=min_val, scale=max_val-min_val, size=n)
    return result

## Imprimir ejemplos dist normal:
np.random.seed(42)
min_val, max_val = 0, 5
print("--- Distribución Uniforme ---")
print(f"Densidad de probabilidad en x=5 para una Uniforme(0,10): {duniform(5, min_val, max_val):.4f}")
print(f"Probabilidad acumulada en x=5 para una Uniforme(0,10): {puniform(5, min_val, max_val):.4f}")
print(f"¿Qué valor de una Uniforme(0,10) tiene una probabilidad acumulada de 0.5? {quniform(0.5, min_val, max_val):.4f}")
print(f"5 valores aleatorios de una Uniforme(0,10): {runiform(5, min_val, max_val)}")

data = np.arange(-5, 5, 0.01)

pmf = duniform(data, min_val = min_val, max_val = max_val)
cdf = puniform(data, min_val = min_val, max_val = max_val)
ppf = quniform(data, min_val = min_val, max_val = max_val)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].plot(data, pmf, "r-")
axis[1].plot(data, cdf, "b-")
axis[2].plot(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# --- Distribución Uniforme ---
# Densidad de probabilidad en x=5 para una Uniforme(0,10): 0.2000
# Probabilidad acumulada en x=5 para una Uniforme(0,10): 1.0000
# ¿Qué valor de una Uniforme(0,10) tiene una probabilidad acumulada de 0.5? 2.5000
# 5 valores aleatorios de una Uniforme(0,10): [1.87270059 4.75357153 3.65996971 2.99329242 0.7800932 ]
